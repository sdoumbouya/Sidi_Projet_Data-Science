# %% [markdown]
# <div align="left"><img src="jedha.png" style="height:40px"></div>
# <br>
# <div align="center"><span style="font-family:Lucida Caligraphy;font-size:26px;color:red">Projet :Uber  </span></div><br><br>
# <div align="right"> </div>
# <div align="center"><span style="font-family:Lucida Caligraphy;font-size:32px;color:green">Localisation des points stratétiques des chauffeurs d'uber pour optimiser ses deplacements dans la ville de New York en Septembre 2014.  </span></div><br><br>
# <div align="center"><span style="font-family:Lucida Caligraphy;font-size:25px;color:blue">Sidi DOUMBOUYA & Abou DIENG</span></div><br><br>
# <hr>

# %% [markdown]
# ##  Objectif

# %% [markdown]
# Le but de ce projet est d'optimiser les points stratégiques des chauffeurs Uber dans la ville de New York en utilisant les techniques de clustering de Machine Learning. Pour ce faire, nous allons essayer de répondre les questions suivantes :
# - Trouver le nombre de clusters optimum
# - Localiser ces clusters sur une map
# - Séparer ces clusters en fonction des périodes de la journée
# - Regarder la différence KMeans et DBSCAN
#
# Nous utilisons les données Uber pour le mois de septembre 2014 contenant 1028135 d'observations pour quatre variables :
# 1.     Date/Time: La date et l'heure du ramassage de l'Uber.
# 2.     Lat (Latitude): La latitude de l'Uber pickup
# 3.     Lon (Longitude):La longitude du pick-up Uber.
# 4.     Base: le code de la société de base TLC affiliée au pick-up Uber.

# %% [markdown]
# ####  *Importation des librairies*

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm

from sklearn.cluster import MiniBatchKMeans
# Bokeh
#!pip install gmplot
from bokeh.io import output_file, show
from bokeh.models import ColumnDataSource, GMapOptions
from bokeh.plotting import gmap

from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
import seaborn as sns

# %%
url1 = "https://raw.githubusercontent.com/fivethirtyeight/uber-tlc-foil-response/master/uber-trip-data/uber-raw-data-sep14.csv"

# %%
df = pd.read_csv(url1)

# %%
print(df.info())
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1028136 entries, 0 to 1028135
# Data columns (total 4 columns):
#  #   Column     Non-Null Count    Dtype
# ---  ------     --------------    -----
#  0   Date/Time  1028136 non-null  object
#  1   Lat        1028136 non-null  float64
#  2   Lon        1028136 non-null  float64
#  3   Base       1028136 non-null  object
# dtypes: float64(2), object(2)
# memory usage: 31.4+ MB
# None
#           Date/Time      Lat      Lon    Base
# 0  9/1/2014 0:01:00  40.2201 -74.0021  B02512
# 1  9/1/2014 0:01:00  40.7500 -74.0027  B02512
# 2  9/1/2014 0:03:00  40.7559 -73.9864  B02512
# 3  9/1/2014 0:06:00  40.7450 -73.9889  B02512
# 4  9/1/2014 0:11:00  40.8145 -73.9444  B02512

# %% [markdown]
# ## 1. Nombre de clusters optimum

# %% [markdown]
# #### Selection de features

# %% [markdown]
# - Latitude
# - Longitude

# %%
X = df[['Lat','Lon']].sample(10000)

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10000 entries, 1016597 to 794604
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Lat     10000 non-null  float64
#  1   Lon     10000 non-null  float64
# dtypes: float64(2)
# memory usage: 234.4 KB

# %% [markdown]
# ### *Normalisation des données*

# %%
sc= StandardScaler()
X_scaled = pd.DataFrame(sc.fit_transform(X.values), columns=X.columns)

# %% [markdown]
# ### *Méthode de Elbow pour trouvé le nombre de Clusters optimal*

# %%
distortions = []
K = range(1,11)
for k in K:
    kmeanModel = KMeans(n_clusters=k)
    kmeanModel.fit(X_scaled)
    distortions.append(kmeanModel.inertia_)

# %%
plt.figure(figsize=(10,6))
plt.plot(K, distortions, 'bx-')
plt.xlabel('Number of clusters')
plt.ylabel('WC55')
plt.title('The Elbow Method showing the optimal k')
plt.show()

# %% [markdown]
# D'après le graphique du coude ci-dessus, nous pouvons voir qu'après K=3, il y a une réduction significative. Nous pouvons choisir entre 3 ou 4 grappes. Nous en avons choisi 3 pour cet ensemble de données.

# %% [markdown]
# ## 2. Clusters sur une map

# %%
kmeans = MiniBatchKMeans(n_clusters=3)
kmeans.fit(X)
kmeans.cluster_centers_
kmeans.labels_
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
output_file("gmap.html")

map_options = GMapOptions(lat=40.7128, lng=-74.0060, map_type="roadmap", zoom=10)
p = gmap("AIzaSyB-E81VWnuGE2A9iXgHHI3lz5ZOvbRIN3A", map_options, title="New York")

centroid = ColumnDataSource(data=dict(lat=kmeans.cluster_centers_[:,0],
                                      lon=kmeans.cluster_centers_[:,1]))

cluster_1 = ColumnDataSource(data=dict(lat=X[kmeans.labels_== 0].iloc[:,0],
                                             lon=X[kmeans.labels_== 0].iloc[:,1]))
cluster_2 = ColumnDataSource(data=dict(lat=X[kmeans.labels_== 1].iloc[:,0],
                                             lon=X[kmeans.labels_== 1].iloc[:,1]))
cluster_3 = ColumnDataSource(data=dict(lat=X[kmeans.labels_== 2].iloc[:,0],
                                             lon=X[kmeans.labels_== 2].iloc[:,1]))
cluster_4 = ColumnDataSource(data=dict(lat=X[kmeans.labels_== 3].iloc[:,0],
                                             lon=X[kmeans.labels_== 3].iloc[:,1]))
cluster_5 = ColumnDataSource(data=dict(lat=X[kmeans.labels_== 4].iloc[:,0],
                                             lon=X[kmeans.labels_== 4].iloc[:,1]))
cluster_6 = ColumnDataSource(data=dict(lat=X[kmeans.labels_== 5].iloc[:,0],
                                             lon=X[kmeans.labels_== 5].iloc[:,1]))

p.circle(x="lon", y="lat", size=8, fill_color="red", fill_alpha=0.8, source=cluster_1)
p.circle(x="lon", y="lat", size=8, fill_color="green", fill_alpha=0.8, source=cluster_2)
p.circle(x="lon", y="lat", size=8, fill_color="yellow", fill_alpha=0.8, source=cluster_3)
p.circle(x="lon", y="lat", size=8, fill_color="blue", fill_alpha=0.8, source=cluster_4)
p.circle(x="lon", y="lat", size=8, fill_color="magenta", fill_alpha=0.8, source=cluster_5)
p.circle(x="lon", y="lat", size=8, fill_color="white", fill_alpha=0.8, source=cluster_6)
p.circle(x="lon", y="lat", size=15, fill_color="black", fill_alpha=0.8, source=centroid)

show(p)

# %% [markdown]
# <div align="center"><span style="font-family:Lucida Caligraphy;font-size:26px;color:blue">Clusters map  </span></div>

# %% [markdown]
# <div align="center"><img src="carte.png" style="height:500px"></div>

# %% [markdown]
# ## 3. Séparation des clusters en fonction des périodes de la journée

# %% [markdown]
# ### Date / Time:

# %%
uber = df.sample(100000)
uber.head()
# Out:
#                  Date/Time      Lat      Lon    Base
# 507256  9/18/2014 19:53:00  40.7411 -73.9857  B02617
# 932495  9/17/2014 17:41:00  40.6647 -73.9511  B02764
# 926064  9/16/2014 16:24:00  40.7454 -73.9715  B02764
# 561074   9/23/2014 8:13:00  40.7185 -74.0028  B02617
# 362139   9/7/2014 16:45:00  40.7696 -73.9844  B02617

# %%
uber['Date/Time'] = pd.to_datetime(uber['Date/Time'])

# %%
uber['Date'] = [d.date() for d in uber['Date/Time']]
uber['Time'] = [d.time() for d in uber['Date/Time']]

# %%
uber['Hour'] = uber['Date/Time'].dt.hour

# %%
uber.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100000 entries, 507256 to 870868
# Data columns (total 7 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Date/Time  100000 non-null  datetime64[ns]
#  1   Lat        100000 non-null  float64
#  2   Lon        100000 non-null  float64
#  3   Base       100000 non-null  object
#  4   Date       100000 non-null  object
#  5   Time       100000 non-null  object
#  6   Hour       100000 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(3)
# memory usage: 6.1+ MB

# %%
uber.head()
# Out:
#                  Date/Time      Lat      Lon    Base        Date      Time  \
# 507256 2014-09-18 19:53:00  40.7411 -73.9857  B02617  2014-09-18  19:53:00
# 932495 2014-09-17 17:41:00  40.6647 -73.9511  B02764  2014-09-17  17:41:00
# 926064 2014-09-16 16:24:00  40.7454 -73.9715  B02764  2014-09-16  16:24:00
# 561074 2014-09-23 08:13:00  40.7185 -74.0028  B02617  2014-09-23  08:13:00
# 362139 2014-09-07 16:45:00  40.7696 -73.9844  B02617  2014-09-07  16:45:00
#
#         Hour
# 507256    19
# 932495    17
# 926064    16
# 561074     8
# 362139    16

# %%
uber.Hour.unique()
# Out:
# array([19, 17, 16,  8, 10,  1, 18, 21, 11,  0, 13, 14,  7,  9, 12, 20, 15,
#         5, 22,  6, 23,  2,  4,  3], dtype=int64)

# %% [markdown]
# - 00h - 06 : Nuit
# - 06 - 10  : Debut de journée
# - 10 - 17  : Journée
# - 17 - 20  : Fin de journée
# - 20 - 00h : Soir

# %%
uber.loc[uber['Hour'] <= 6, 'Hour'] = 0
uber.loc[(uber['Hour'] > 6) & (uber['Hour'] <= 10), 'Hour'] = 1
uber.loc[(uber['Hour'] > 10) & (uber['Hour'] <= 17), 'Hour'] = 2
uber.loc[(uber['Hour'] > 17) & (uber['Hour'] <= 20), 'Hour'] = 3
uber.loc[uber['Hour'] > 20, 'Hour'] = 4

# %%
uber['Hour']=uber['Hour'].map({0:"Nuit",1:"Debut de journée", 2:"Journée",3:"Fin de journée", 4:"Soir"})

# %%
uber.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100000 entries, 507256 to 870868
# Data columns (total 7 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Date/Time  100000 non-null  datetime64[ns]
#  1   Lat        100000 non-null  float64
#  2   Lon        100000 non-null  float64
#  3   Base       100000 non-null  object
#  4   Date       100000 non-null  object
#  5   Time       100000 non-null  object
#  6   Hour       100000 non-null  object
# dtypes: datetime64[ns](1), float64(2), object(4)
# memory usage: 6.1+ MB

# %%
uber.head(5)
# Out:
#                  Date/Time      Lat      Lon    Base        Date      Time  \
# 507256 2014-09-18 19:53:00  40.7411 -73.9857  B02617  2014-09-18  19:53:00
# 932495 2014-09-17 17:41:00  40.6647 -73.9511  B02764  2014-09-17  17:41:00
# 926064 2014-09-16 16:24:00  40.7454 -73.9715  B02764  2014-09-16  16:24:00
# 561074 2014-09-23 08:13:00  40.7185 -74.0028  B02617  2014-09-23  08:13:00
# 362139 2014-09-07 16:45:00  40.7696 -73.9844  B02617  2014-09-07  16:45:00
#
#                     Hour
# 507256    Fin de journée
# 932495           Journée
# 926064           Journée
# 561074  Debut de journée
# 362139           Journée

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(data = uber, x="Lat", y="Lon", hue= "Hour")

# %%
uber.Hour.value_counts()
# Out:
# Journée             36720
# Fin de journée      20464
# Debut de journée    15969
# Soir                14381
# Nuit                12466
# Name: Hour, dtype: int64

# %% [markdown]
# En fonction des périodes de la journée, on constate que les deplacements des chauffeurs sont plus fréquents entre 10h et 17h (Journée) puis de 17h à 20h (Fin de journée).

# %% [markdown]
# ## 4. Différence KMeans et DBSCAN

# %% [markdown]
# ### KMeans

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(data = uber, x="Lat", y="Lon")

# %%
X_scaled = StandardScaler().fit_transform(X)

# %%
km = KMeans(n_clusters = 3).fit(X_scaled)
clusters = km.predict(X_scaled)
plt.figure(figsize=(10,6))
sns.scatterplot(X_scaled[:,0], X_scaled[:,1], hue=clusters)

# %% [markdown]
# ### DBSCAN

# %%
from sklearn.cluster import DBSCAN
clusters = DBSCAN(eps=0.5).fit_predict(X_scaled)

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(X_scaled[:,0], X_scaled[:,1], hue=clusters, palette="Pastel1")

# %%
kmeans = KMeans(n_clusters=3, random_state =42)
kmeans.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=3, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=42, tol=0.0001, verbose=0)

# %% [markdown]
# ### Visualisation des centroids

# %%
#storing clusters centroids
centoid = kmeans.cluster_centers_
centoid
# Out:
# array([[ 40.72104936, -73.9936079 ],
#        [ 40.68977566, -73.7664292 ],
#        [ 40.77194103, -73.96200252]])

# %%
clocation = pd.DataFrame(centoid, columns =["Lat","Lon"])

# %%
clocation
# Out:
#          Lat        Lon
# 0  40.721049 -73.993608
# 1  40.689776 -73.766429
# 2  40.771941 -73.962003

# %%
plt.scatter(clocation["Lat"], clocation["Lon"], marker ="x", color ="R", s=50)

# %%
# !pip install folium
import folium
# Converting centroid into lists
centroid = clocation.values.tolist()
# Plotting the centroids on google map using Folium library.
map = folium.Map(location=[40.79658011772687, -73.87341741832425], zoom_start = 25)
for point in range(0, len(centroid)):
    folium.Marker(centroid[point], popup = centroid[point]).add_to(map)
map
# Out:
# Requirement already satisfied: folium in c:\users\sidid\anaconda3\lib\site-packages (0.10.1)
# Requirement already satisfied: branca>=0.3.0 in c:\users\sidid\anaconda3\lib\site-packages (from folium) (0.4.0)
# Requirement already satisfied: numpy in c:\users\sidid\anaconda3\lib\site-packages (from folium) (1.18.1)
# Requirement already satisfied: jinja2>=2.9 in c:\users\sidid\anaconda3\lib\site-packages (from folium) (2.11.1)
# Requirement already satisfied: requests in c:\users\sidid\anaconda3\lib\site-packages (from folium) (2.23.0)
# Requirement already satisfied: six in c:\users\sidid\anaconda3\lib\site-packages (from branca>=0.3.0->folium) (1.14.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\sidid\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (1.1.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\sidid\anaconda3\lib\site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\sidid\anaconda3\lib\site-packages (from requests->folium) (2.9)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\sidid\anaconda3\lib\site-packages (from requests->folium) (1.25.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sidid\anaconda3\lib\site-packages (from requests->folium) (2019.11.28)
# ERROR: Error checking for conflicts.
# Traceback (most recent call last):
#   File "C:\Users\sidid\Anaconda3\lib\site-packages\pip\_vendor\pkg_resources\__init__.py", line 3021, in _dep_map
#     return self.__dep_map
#   File "C:\Users\sidid\Anaconda3\lib\site-packages\pip\_vendor\pkg_resources\__init__.py", line 2815, in __getattr__
#     raise AttributeError(attr)
# AttributeError: _DistInfoDistribution__dep_map
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\sidid\Anaconda3\lib\site-packages\pip\_vendor\pkg_resources\__init__.py", line 3012, in _parsed_pkg_info
#     return self._pkg_info
#   File "C:\Users\sidid\Anaconda3\lib\site-packages\pip\_vendor\pkg_resources\__init__.py", line 2815, in __getattr__
#     raise AttributeError(attr)
# AttributeError: _pkg_info
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\sidid\Anaconda3\lib\site-packages\pip\_internal\commands\install.py", line 517, in _warn_about_conflicts
#     package_set, _dep_info = check_install_conflicts(to_install)
#   File "C:\Users\sidid\Anaconda3\lib\site-packages\pip\_internal\operations\check.py", line 114, in check_install_conflicts
#     package_set, _ = create_package_set_from_installed()
#   File "C:\Users\sidid\Anaconda3\lib\site-packages\pip\_internal\operations\check.py", line 53, in create_package_set_from_installed
#     package_set[name] = PackageDetails(dist.version, dist.requires())
#   File "C:\Users\sidid\Anaconda3\lib\site-packages\pip\_vendor\pkg_resources\__init__.py", line 2736, in requires
#     dm = self._dep_map
#   File "C:\Users\sidid\Anaconda3\lib\site-packages\pip\_vendor\pkg_resources\__init__.py", line 3023, in _dep_map
#     self.__dep_map = self._compute_dependencies()
#   File "C:\Users\sidid\Anaconda3\lib\site-packages\pip\_vendor\pkg_resources\__init__.py", line 3032, in _compute_dependencies
#     for req in self._parsed_pkg_info.get_all('Requires-Dist') or []:
#   File "C:\Users\sidid\Anaconda3\lib\site-packages\pip\_vendor\pkg_resources\__init__.py", line 3014, in _parsed_pkg_info
#     metadata = self.get_metadata(self.PKG_INFO)
#   File "C:\Users\sidid\Anaconda3\lib\site-packages\pip\_vendor\pkg_resources\__init__.py", line 1420, in get_metadata
#     value = self._get(path)
#   File "C:\Users\sidid\Anaconda3\lib\site-packages\pip\_vendor\pkg_resources\__init__.py", line 1616, in _get
#     with open(path, 'rb') as stream:
# FileNotFoundError: [Errno 2] No such file or directory: 'c:\\users\\sidid\\anaconda3\\lib\\site-packages\\pyodbc-4.0.27.dist-info\\METADATA'
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
## viz centroids
# predition in a new location
new_location = [( 40.6556, -73.5631)]
kmeans.predict(new_location)
# Out:
# array([1])
